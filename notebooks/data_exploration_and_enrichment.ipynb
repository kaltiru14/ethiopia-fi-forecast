# %% [markdown]
# # Task 1 — Data Exploration & Enrichment
# **Author:** Kudu T
# **Date:** 2026-01-30
#
# Objective: Understand the starter dataset for Ethiopia's financial inclusion and enrich it with additional observations, events, or impact links.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

pd.set_option("display.max_columns", None)

# %%
# File paths
file_path = "../data/raw/ethiopia_fi_unified_data.xlsx"
ref_codes_path = "../data/raw/reference_codes.xlsx"

# Load Excel sheets
xls = pd.ExcelFile(file_path)
df_data = pd.read_excel(xls, sheet_name="ethiopia_fi_unified_data")
df_impact = pd.read_excel(xls, sheet_name="Impact_sheet")

# Load reference codes
ref_codes = pd.read_excel(ref_codes_path)

# Quick look
df_data.head(), df_impact.head(), ref_codes.head()
# Out:
# (  record_id  record_type category  pillar               indicator  \
#  0  REC_0001  observation      NaN  ACCESS  Account Ownership Rate
#  1  REC_0002  observation      NaN  ACCESS  Account Ownership Rate
#  2  REC_0003  observation      NaN  ACCESS  Account Ownership Rate
#  3  REC_0004  observation      NaN  ACCESS  Account Ownership Rate
#  4  REC_0005  observation      NaN  ACCESS  Account Ownership Rate
#
#    indicator_code indicator_direction  value_numeric value_text  value_type  \
#  0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
#  1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
#  2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
#  3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
#  4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#     ... impact_direction impact_magnitude impact_estimate lag_months  \
#  0  ...              NaN              NaN             NaN        NaN
#  1  ...              NaN              NaN             NaN        NaN
#  2  ...              NaN              NaN             NaN        NaN
#  3  ...              NaN              NaN             NaN        NaN
#  4  ...              NaN              NaN             NaN        NaN
#
#    evidence_basis comparable_country collected_by  collection_date  \
#  0            NaN    Example_Trainee   2025-01-20              NaN
#  1            NaN    Example_Trainee   2025-01-20              NaN
#  2            NaN    Example_Trainee   2025-01-20              NaN
#  3            NaN    Example_Trainee   2025-01-20              NaN
#  4            NaN    Example_Trainee   2025-01-20              NaN
#
#            original_text notes
#  0         Baseline year   NaN
#  1                   NaN   NaN
#  2                   NaN   NaN
#  3  Gender disaggregated   NaN
#  4  Gender disaggregated   NaN
#
#  [5 rows x 34 columns],
#    record_id parent_id  record_type  category         pillar  \
#  0  IMP_0001  EVT_0001  impact_link       NaN         ACCESS
#  1  IMP_0002  EVT_0001  impact_link       NaN          USAGE
#  2  IMP_0003  EVT_0001  impact_link       NaN          USAGE
#  3  IMP_0004  EVT_0002  impact_link       NaN         ACCESS
#  4  IMP_0005  EVT_0002  impact_link       NaN  AFFORDABILITY
#
#                                  indicator  indicator_code  \
#  0    Telebirr effect on Account Ownership             NaN
#  1       Telebirr effect on Telebirr Users             NaN
#  2     Telebirr effect on P2P Transactions             NaN
#  3         Safaricom effect on 4G Coverage             NaN
#  4  Safaricom effect on Data Affordability             NaN
#
#     indicator_direction  value_numeric  value_text  ... impact_direction  \
#  0                  NaN           15.0         NaN  ...         increase
#  1                  NaN            NaN         NaN  ...         increase
#  2                  NaN           25.0         NaN  ...         increase
#  3                  NaN           15.0         NaN  ...         increase
#  4                  NaN          -20.0         NaN  ...         decrease
#
#    impact_magnitude impact_estimate  lag_months  evidence_basis  \
#  0             high            15.0          12      literature
#  1             high             NaN           3       empirical
#  2             high            25.0           6       empirical
#  3           medium            15.0          12       empirical
#  4           medium           -20.0          12      literature
#
#     comparable_country     collected_by collection_date  original_text  \
#  0               Kenya  Example_Trainee      2025-01-20            NaN
#  1                 NaN  Example_Trainee      2025-01-20            NaN
#  2                 NaN  Example_Trainee      2025-01-20            NaN
#  3                 NaN  Example_Trainee      2025-01-20            NaN
#  4              Rwanda  Example_Trainee      2025-01-20            NaN
#
#                                      notes
#  0  Kenya M-Pesa showed +20pp over 5 years
#  1           Direct subscriber acquisition
#  2             New digital payment channel
#  3     Network investment from competition
#  4    Competition typically reduces prices
#
#  [5 rows x 35 columns],
#           field         code  \
#  0  record_type  observation
#  1  record_type        event
#  2  record_type  impact_link
#  3  record_type       target
#  4  record_type     baseline
#
#                                           description applies_to
#  0                Actual measured value from a source        All
#  1            Policy launch market event or milestone        All
#  2  Relationship between event and indicator (link...        All
#  3                     Policy target or official goal        All
#  4                      Starting point for comparison        All  )

# %% [markdown]
# ## Unified Schema Overview
#
# The dataset follows a unified schema design where:
# - All records share the same columns
# - The `record_type` field determines how each row is interpreted
#
# Record types include:
# - observation: measured indicators (e.g., Findex, infrastructure)
# - event: policies, product launches, milestones
# - impact_link: modeled relationships between events and indicators
# - target: official policy goals
#
# Events are intentionally NOT assigned to pillars.
# Their effects on Access or Usage are defined only through impact_link records.

# %%
# Separate record types
obs = df_data[df_data["record_type"] == "observation"]
events = df_data[df_data["record_type"] == "event"]

print("Observations:", len(obs))
print("Events:", len(events))

# Record type counts
print(df_data["record_type"].value_counts())

# Pillar coverage
print(df_data["pillar"].value_counts(dropna=False))

# Observation date range
print(df_data["observation_date"].min(), df_data["observation_date"].max())

# Unique indicators
print(df_data['indicator_code'].value_counts())

# Source types and confidence
print(df_data['source_type'].value_counts())
print(df_data['confidence'].value_counts())

# Indicator coverage across years
indicator_coverage = obs.groupby("indicator_code")["observation_date"].nunique().sort_values()
indicator_coverage
# Out:
# Observations: 31
# Events: 12
# record_type
# observation    31
# event          12
# target          3
# Name: count, dtype: int64
# pillar
# ACCESS           17
# NaN              12
# USAGE            11
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64
# 2014-12-31 00:00:00 2030-12-31 00:00:00
# indicator_code
# ACC_OWNERSHIP         7
# ACC_FAYDA             4
# ACC_MM_ACCOUNT        2
# ACC_4G_COV            2
# USG_P2P_COUNT         2
# GEN_MM_SHARE          2
# GEN_GAP_ACC           2
# USG_ATM_COUNT         1
# USG_P2P_VALUE         1
# USG_CROSSOVER         1
# USG_TELEBIRR_USERS    1
# USG_TELEBIRR_VALUE    1
# USG_ATM_VALUE         1
# ACC_MOBILE_PEN        1
# USG_MPESA_ACTIVE      1
# USG_MPESA_USERS       1
# AFF_DATA_INCOME       1
# USG_ACTIVE_RATE       1
# GEN_GAP_MOBILE        1
# EVT_TELEBIRR          1
# EVT_SAFARICOM         1
# EVT_MPESA             1
# EVT_FAYDA             1
# EVT_FX_REFORM         1
# EVT_CROSSOVER         1
# EVT_MPESA_INTEROP     1
# EVT_ETHIOPAY          1
# EVT_NFIS2             1
# EVT_SAFCOM_PRICE      1
# ACC_SMARTPHONE_PCT    1
# Name: count, dtype: int64
# source_type
# operator           15
# survey             10
# regulator           7
# research            4
# policy              3
# calculated          2
# news                2
# industry_report     1
# government          1
# Name: count, dtype: int64
# confidence
# high      40
# medium     6
# Name: count, dtype: int64
# indicator_code
# ACC_MOBILE_PEN        1
# ACC_SMARTPHONE_PCT    1
# AFF_DATA_INCOME       1
# USG_ATM_VALUE         1
# USG_ATM_COUNT         1
# USG_ACTIVE_RATE       1
# GEN_MM_SHARE          1
# GEN_GAP_MOBILE        1
# USG_MPESA_ACTIVE      1
# USG_CROSSOVER         1
# USG_MPESA_USERS       1
# USG_P2P_VALUE         1
# USG_TELEBIRR_USERS    1
# USG_TELEBIRR_VALUE    1
# ACC_MM_ACCOUNT        2
# ACC_4G_COV            2
# GEN_GAP_ACC           2
# USG_P2P_COUNT         2
# ACC_FAYDA             3
# ACC_OWNERSHIP         4
# Name: observation_date, dtype: int64

# %% [markdown]
# **Observations:**
# - 30 observations, 10 events, 3 targets
# - ACCESS and USAGE pillars are most common
# - Observation years range from 2011–2024
# - High-confidence events include Telebirr launch, NFIS policy, M-Pesa entry

# %%
events_df = df_data[df_data["record_type"] == "event"][
    ["observation_date", "category", "original_text", "notes", "confidence"]
].sort_values("observation_date")

events_df
# Out:
#    observation_date        category  \
# 33       2021-05-17  product_launch
# 41       2021-09-01          policy
# 34       2022-08-01    market_entry
# 45       2023-06-01          policy
# 35       2023-08-01  product_launch
# 36       2024-01-01  infrastructure
# 37       2024-07-29          policy
# 38       2024-10-01       milestone
# 39       2025-10-27     partnership
# 42       2025-12-15         pricing
# 40       2025-12-18  infrastructure
# 43              NaT          policy
#
#                                         original_text  \
# 33       First major mobile money service in Ethiopia
# 41       5-year national financial inclusion strategy
# 34                      End of state telecom monopoly
# 45  Ethiopia launched the Fayda Digital ID system ...
# 35                        Second mobile money entrant
# 36               National biometric digital ID system
# 37                              Birr float introduced
# 38            Historic: digital > cash for first time
# 39                   Full interoperability for M-Pesa
# 42             Data and voice prices increased 20-82%
# 40                  National real-time payment system
# 43  Ethiopia launched the Fayda Digital ID system ...
#
#                                                 notes confidence
# 33                                                NaN       high
# 41                                                NaN       high
# 34                                                NaN       high
# 45  Digital ID reduces KYC barriers for account op...     medium
# 35                                                NaN       high
# 36                                                NaN       high
# 37                                                NaN       high
# 38                                                NaN       high
# 39                                                NaN       high
# 42                                                NaN       high
# 40                                                NaN       high
# 43  Digital ID reduces KYC barriers for account op...     medium

# %% [markdown]
# **Insight:**
# Core indicators (e.g. Account Ownership) have multi-year coverage,
# while infrastructure and usage indicators are sparse.
# This motivates targeted data enrichment.
# **Event Overview:**
# - Includes product launches, policies, infrastructure investments, milestones
# - Important events with high confidence:
#   - Telebirr launch (May 2021)
#   - NFIS policy (Sept 2021)
#   - M-Pesa market entry (Aug 2023)

# %%
new_observation = {
    "record_id": "OBS_ENRICH_001",
    "record_type": "observation",
    "pillar": "ACCESS",
    "indicator": "Smartphone penetration",
    "indicator_code": "ACC_SMARTPHONE_PCT",
    "indicator_direction": "higher_better",
    "value_numeric": 28.0,
    "value_type": "percentage",
    "unit": "%",
    "observation_date": pd.to_datetime("2023-01-01"),
    "source_name": "GSMA",
    "source_type": "industry_report",
    "source_url": "https://www.gsma.com",
    "confidence": "medium",
    "original_text": "Smartphone penetration in Ethiopia reached approximately 28% in 2023.",
    "collected_by": "Kudu T",
    "collection_date": pd.to_datetime("2026-01-30"),
    "notes": "Smartphone access enables app-based digital financial services."
}

df_data = pd.concat([df_data, pd.DataFrame([new_observation])], ignore_index=True)

df_data[df_data["record_id"] == "OBS_ENRICH_001"]
# Out:
#          record_id  record_type category  pillar               indicator  \
# 44  OBS_ENRICH_001  observation      NaN  ACCESS  Smartphone penetration
#
#         indicator_code indicator_direction  value_numeric value_text  \
# 44  ACC_SMARTPHONE_PCT       higher_better           28.0        NaN
#
#     value_type unit observation_date period_start period_end fiscal_year  \
# 44  percentage    %       2023-01-01          NaT        NaT         NaN
#
#    gender location  region source_name      source_type            source_url  \
# 44    NaN      NaN     NaN        GSMA  industry_report  https://www.gsma.com
#
#    confidence  related_indicator  relationship_type  impact_direction  \
# 44     medium                NaN                NaN               NaN
#
#     impact_magnitude  impact_estimate  lag_months  evidence_basis  \
# 44               NaN              NaN         NaN             NaN
#
#    comparable_country collected_by      collection_date  \
# 44                NaN       Kudu T  2026-01-30 00:00:00
#
#                                         original_text  \
# 44  Smartphone penetration in Ethiopia reached app...
#
#                                                 notes event_name event_date
# 44  Smartphone access enables app-based digital fi...        NaN        NaN

# %%
new_event = {
    "record_id": "EVT_ENRICH_001",
    "record_type": "event",
    "category": "policy",
    "event_name": "Fayda Digital ID national rollout",
    "observation_date": pd.to_datetime("2023-06-01"),
    "source_name": "Government of Ethiopia",
    "source_type": "government",
    "source_url": "https://id.gov.et",
    "confidence": "medium",
    "original_text": "Ethiopia launched the Fayda Digital ID system to enable access to digital services.",
    "collected_by": "Kudu T",
    "collection_date": pd.to_datetime("2026-01-30"),
    "notes": "Digital ID reduces KYC barriers for account opening."
}

df_data = pd.concat([df_data, pd.DataFrame([new_event])], ignore_index=True)

df_data[df_data["record_id"] == "EVT_ENRICH_001"]
# Out:
#          record_id record_type category pillar indicator indicator_code  \
# 43  EVT_ENRICH_001       event   policy    NaN       NaN            NaN
# 45  EVT_ENRICH_001       event   policy    NaN       NaN            NaN
#
#    indicator_direction  value_numeric value_text value_type unit  \
# 43                 NaN            NaN        NaN        NaN  NaN
# 45                 NaN            NaN        NaN        NaN  NaN
#
#    observation_date period_start period_end fiscal_year gender location  \
# 43              NaT          NaT        NaT         NaN    NaN      NaN
# 45       2023-06-01          NaT        NaT         NaN    NaN      NaN
#
#     region             source_name source_type         source_url confidence  \
# 43     NaN  Government of Ethiopia         NaN  https://id.gov.et     medium
# 45     NaN  Government of Ethiopia  government  https://id.gov.et     medium
#
#     related_indicator  relationship_type  impact_direction  impact_magnitude  \
# 43                NaN                NaN               NaN               NaN
# 45                NaN                NaN               NaN               NaN
#
#     impact_estimate  lag_months  evidence_basis comparable_country  \
# 43              NaN         NaN             NaN                NaN
# 45              NaN         NaN             NaN                NaN
#
#    collected_by      collection_date  \
# 43       Kudu T           2026-01-30
# 45       Kudu T  2026-01-30 00:00:00
#
#                                         original_text  \
# 43  Ethiopia launched the Fayda Digital ID system ...
# 45  Ethiopia launched the Fayda Digital ID system ...
#
#                                                 notes  \
# 43  Digital ID reduces KYC barriers for account op...
# 45  Digital ID reduces KYC barriers for account op...
#
#                            event_name  event_date
# 43  Fayda Digital ID national rollout  2023-06-01
# 45  Fayda Digital ID national rollout         NaN

# %%
new_impact_link = {
    "record_id": "IMP_ENRICH_001",
    "parent_id": "EVT_ENRICH_001",
    "record_type": "impact_link",
    "pillar": "ACCESS",
    "related_indicator": "ACC_OWNERSHIP",
    "impact_direction": "positive",
    "impact_magnitude": 0.15,
    "lag_months": 6,
    "evidence_basis": "Comparable evidence from Kenya and Rwanda digital ID programs",
    "confidence": "medium",
    "collected_by": "Kudu T",
    "collection_date": pd.to_datetime("2026-01-30"),
    "original_text": "Digital ID programs reduce onboarding friction for financial accounts.",
    "notes": "Effect size conservative due to implementation and adoption risks."
}

df_impact = pd.concat([df_impact, pd.DataFrame([new_impact_link])], ignore_index=True)

df_impact[df_impact["record_id"] == "IMP_ENRICH_001"]
# Out:
#          record_id       parent_id  record_type  category  pillar indicator  \
# 16  IMP_ENRICH_001  EVT_ENRICH_001  impact_link       NaN  ACCESS       NaN
#
#     indicator_code  indicator_direction  value_numeric  value_text value_type  \
# 16             NaN                  NaN            NaN         NaN        NaN
#
#    unit observation_date  period_start  period_end  fiscal_year gender  \
# 16  NaN              NaT           NaN         NaN          NaN    NaN
#
#    location  region  source_name  source_type  source_url confidence  \
# 16      NaN     NaN          NaN          NaN         NaN     medium
#
#    related_indicator relationship_type impact_direction impact_magnitude  \
# 16     ACC_OWNERSHIP               NaN         positive             0.15
#
#     impact_estimate  lag_months  \
# 16              NaN           6
#
#                                        evidence_basis comparable_country  \
# 16  Comparable evidence from Kenya and Rwanda digi...                NaN
#
#    collected_by      collection_date  \
# 16       Kudu T  2026-01-30 00:00:00
#
#                                         original_text  \
# 16  Digital ID programs reduce onboarding friction...
#
#                                                 notes
# 16  Effect size conservative due to implementation...

# %%
print("New observations added:")
print(df_data[df_data["record_id"] == "OBS_ENRICH_001"])

print("\nNew events added:")
print(df_data[df_data["record_id"] == "EVT_ENRICH_001"])

print("\nNew impact links added:")
print(df_impact[df_impact["record_id"] == "IMPACT_ENRICH_001"])
# Out:
# New observations added:
#          record_id  record_type category  pillar               indicator  \
# 44  OBS_ENRICH_001  observation      NaN  ACCESS  Smartphone penetration
#
#         indicator_code indicator_direction  value_numeric value_text  \
# 44  ACC_SMARTPHONE_PCT       higher_better           28.0        NaN
#
#     value_type unit observation_date period_start period_end fiscal_year  \
# 44  percentage    %       2023-01-01          NaT        NaT         NaN
#
#    gender location  region source_name      source_type            source_url  \
# 44    NaN      NaN     NaN        GSMA  industry_report  https://www.gsma.com
#
#    confidence  related_indicator  relationship_type  impact_direction  \
# 44     medium                NaN                NaN               NaN
#
#     impact_magnitude  impact_estimate  lag_months  evidence_basis  \
# 44               NaN              NaN         NaN             NaN
#
#    comparable_country collected_by      collection_date  \
# 44                NaN       Kudu T  2026-01-30 00:00:00
#
#                                         original_text  \
# 44  Smartphone penetration in Ethiopia reached app...
#
#                                                 notes event_name event_date
# 44  Smartphone access enables app-based digital fi...        NaN        NaN
#
# New events added:
#          record_id record_type category pillar indicator indicator_code  \
# 43  EVT_ENRICH_001       event   policy    NaN       NaN            NaN
# 45  EVT_ENRICH_001       event   policy    NaN       NaN            NaN
#
#    indicator_direction  value_numeric value_text value_type unit  \
# 43                 NaN            NaN        NaN        NaN  NaN
# 45                 NaN            NaN        NaN        NaN  NaN
#
#    observation_date period_start period_end fiscal_year gender location  \
# 43              NaT          NaT        NaT         NaN    NaN      NaN
# 45       2023-06-01          NaT        NaT         NaN    NaN      NaN
#
#     region             source_name source_type         source_url confidence  \
# 43     NaN  Government of Ethiopia         NaN  https://id.gov.et     medium
# 45     NaN  Government of Ethiopia  government  https://id.gov.et     medium
#
#     related_indicator  relationship_type  impact_direction  impact_magnitude  \
# 43                NaN                NaN               NaN               NaN
# 45                NaN                NaN               NaN               NaN
#
#     impact_estimate  lag_months  evidence_basis comparable_country  \
# 43              NaN         NaN             NaN                NaN
# 45              NaN         NaN             NaN                NaN
#
#    collected_by      collection_date  \
# 43       Kudu T           2026-01-30
# 45       Kudu T  2026-01-30 00:00:00
#
#                                         original_text  \
# 43  Ethiopia launched the Fayda Digital ID system ...
# 45  Ethiopia launched the Fayda Digital ID system ...
#
#                                                 notes  \
# 43  Digital ID reduces KYC barriers for account op...
# 45  Digital ID reduces KYC barriers for account op...
#
#                            event_name  event_date
# 43  Fayda Digital ID national rollout  2023-06-01
# 45  Fayda Digital ID national rollout         NaN
#
# New impact links added:
#             record_id       parent_id  record_type  category  pillar  \
# 14  IMPACT_ENRICH_001  REC_ENRICH_001  impact_link       NaN   USAGE
# 15  IMPACT_ENRICH_001  EVT_ENRICH_001  impact_link       NaN  ACCESS
#
#    indicator  indicator_code  indicator_direction  value_numeric  value_text  \
# 14       NaN             NaN                  NaN            NaN         NaN
# 15       NaN             NaN                  NaN            NaN         NaN
#
#    value_type unit observation_date  period_start  period_end  fiscal_year  \
# 14        NaN  NaN              NaT           NaN         NaN          NaN
# 15        NaN  NaN              NaT           NaN         NaN          NaN
#
#    gender location  region  source_name  source_type  source_url confidence  \
# 14    NaN      NaN     NaN          NaN          NaN         NaN        NaN
# 15    NaN      NaN     NaN          NaN          NaN         NaN     medium
#
#       related_indicator relationship_type impact_direction impact_magnitude  \
# 14  USG_DIGITAL_PAYMENT               NaN         positive              0.2
# 15        ACC_OWNERSHIP               NaN         positive             0.15
#
#     impact_estimate  lag_months  \
# 14              NaN          12
# 15              NaN           6
#
#                                        evidence_basis comparable_country  \
# 14      Evidence from Kenya, Rwanda, and GSMA reports                NaN
# 15  Comparable evidence from Kenya and Rwanda digi...                NaN
#
#    collected_by collection_date  \
# 14       Kudu T      2026-01-29
# 15       Kudu T      2026-01-30
#
#                                         original_text  \
# 14  Higher smartphone penetration enables app-base...
# 15  Digital ID programs reduce onboarding friction...
#
#                                                 notes
# 14  Impact magnitude is conservative due to Ethiop...
# 15  Effect size conservative due to implementation...

# %%
df_event_impact = df_impact.merge(
    df_data[df_data["record_type"] == "event"][["record_id", "observation_date", "category", "original_text"]],
    left_on="parent_id",
    right_on="record_id",
    how="left",
    suffixes=("", "_event")
)

df_event_impact[[
    "observation_date_event",
    "category_event",
    "original_text_event",
    "pillar",
    "related_indicator",
    "impact_direction",
    "impact_magnitude",
    "lag_months"
]]
# Out:
#    observation_date_event  category_event  \
# 0              2021-05-17  product_launch
# 1              2021-05-17  product_launch
# 2              2021-05-17  product_launch
# 3              2022-08-01    market_entry
# 4              2022-08-01    market_entry
# 5              2023-08-01  product_launch
# 6              2023-08-01  product_launch
# 7              2024-01-01  infrastructure
# 8              2024-01-01  infrastructure
# 9              2024-07-29          policy
# 10             2025-10-27     partnership
# 11             2025-10-27     partnership
# 12             2025-12-18  infrastructure
# 13             2025-12-15         pricing
# 14                    NaT             NaN
# 15                    NaT          policy
# 16             2023-06-01          policy
# 17                    NaT          policy
# 18             2023-06-01          policy
#
#                                   original_text_event         pillar  \
# 0        First major mobile money service in Ethiopia         ACCESS
# 1        First major mobile money service in Ethiopia          USAGE
# 2        First major mobile money service in Ethiopia          USAGE
# 3                       End of state telecom monopoly         ACCESS
# 4                       End of state telecom monopoly  AFFORDABILITY
# 5                         Second mobile money entrant          USAGE
# 6                         Second mobile money entrant         ACCESS
# 7                National biometric digital ID system         ACCESS
# 8                National biometric digital ID system         GENDER
# 9                               Birr float introduced  AFFORDABILITY
# 10                   Full interoperability for M-Pesa          USAGE
# 11                   Full interoperability for M-Pesa          USAGE
# 12                  National real-time payment system          USAGE
# 13             Data and voice prices increased 20-82%  AFFORDABILITY
# 14                                                NaN          USAGE
# 15  Ethiopia launched the Fayda Digital ID system ...         ACCESS
# 16  Ethiopia launched the Fayda Digital ID system ...         ACCESS
# 17  Ethiopia launched the Fayda Digital ID system ...         ACCESS
# 18  Ethiopia launched the Fayda Digital ID system ...         ACCESS
#
#       related_indicator impact_direction impact_magnitude  lag_months
# 0         ACC_OWNERSHIP         increase             high          12
# 1    USG_TELEBIRR_USERS         increase             high           3
# 2         USG_P2P_COUNT         increase             high           6
# 3            ACC_4G_COV         increase           medium          12
# 4       AFF_DATA_INCOME         decrease           medium          12
# 5       USG_MPESA_USERS         increase             high           3
# 6        ACC_MM_ACCOUNT         increase           medium           6
# 7         ACC_OWNERSHIP         increase           medium          24
# 8           GEN_GAP_ACC         decrease           medium          24
# 9       AFF_DATA_INCOME         increase             high           3
# 10     USG_MPESA_ACTIVE         increase           medium           3
# 11        USG_P2P_COUNT         increase           medium           3
# 12        USG_P2P_COUNT         increase           medium           6
# 13      AFF_DATA_INCOME         increase              low           1
# 14  USG_DIGITAL_PAYMENT         positive              0.2          12
# 15        ACC_OWNERSHIP         positive             0.15           6
# 16        ACC_OWNERSHIP         positive             0.15           6
# 17        ACC_OWNERSHIP         positive             0.15           6
# 18        ACC_OWNERSHIP         positive             0.15           6

# %%
df_data.to_excel(
    "../data/processed/ethiopia_fi_unified_data_enriched.xlsx",
    index=False
)

df_impact.to_excel(
    "../data/processed/impact_links_enriched.xlsx",
    index=False
)

print("Enriched datasets saved successfully.")
# Out:
# Enriched datasets saved successfully.

# %% [markdown]
# **Next Steps:**
# - Task 2 will perform exploratory data analysis on the enriched dataset
# - Visualize trends in Access and Usage
# - Map events to indicators to estimate historical impact
